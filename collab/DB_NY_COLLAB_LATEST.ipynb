# %% [markdown]
# ## Download the `createguitar.sql` file to source our tables

# %%
# !wget https://raw.githubusercontent.com/SA6246/NYU_Tandon_Databases_Spring/main/createguitar.sql createguitar.sql
# Out:
# --2024-02-17 18:31:54--  https://raw.githubusercontent.com/SA6246/NYU_Tandon_Databases_Spring/main/createguitar.sql
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17509 (17K) [text/plain]
# Saving to: ‘createguitar.sql’
#
# createguitar.sql    100%[===================>]  17.10K  --.-KB/s    in 0s
#
# 2024-02-17 18:31:54 (77.4 MB/s) - ‘createguitar.sql’ saved [17509/17509]
#
# --2024-02-17 18:31:54--  http://createguitar.sql/
# Resolving createguitar.sql (createguitar.sql)... failed: Name or service not known.
# wget: unable to resolve host address ‘createguitar.sql’
# FINISHED --2024-02-17 18:31:54--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 17K in 0s (77.4 MB/s)

# %% [markdown]
# ## Install our `mysql` python dependencies

# %%
# !pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 19.7 MB/s eta 0:00:00
# ...

# %%
# !apt-get -y install mysql-server
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl libfcgi-bin libfcgi-perl
#   libfcgi0ldbl libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl liblwp-mediatypes-perl libmecab2 libprotobuf-lite23
#   liburi-perl mecab-ipadic mecab-ipadic-utf8 mecab-utils mysql-client-8.0 mysql-client-core-8.0
#   mysql-server-8.0 mysql-server-core-8.0
# Suggested packages:
#   libdata-dump-perl libipc-sharedcache-perl libbusiness-isbn-perl libwww-perl mailx tinyca
# The following NEW packages will be installed:
#   libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl libfcgi-bin libfcgi-perl
#   libfcgi0ldbl libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
# ...

# %% [markdown]
# ## Start our mysql server the following cells:
# - Change the server password
# - Sources the tables for our DB fromt he `createguitar.sql` file
# - Exits from the server console

# %%
# !service mysql start
# Out:
#  * Starting MySQL database server mysqld
# su: warning: cannot change directory to /nonexistent: No such file or directory
#    ...done.

# %%
# !mysql -u root -proot -e "ALTER USER 'root'@'localhost' IDENTIFIED BY 'root'; source createguitar.sql;"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.

# %%
# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH 'mysql_native_password' BY 'root';FLUSH PRIVILEGES;"

# %%
import mysql.connector

# Create a connection to the MySQL server
conn = mysql.connector.connect(user='root', password='root', host='localhost')

# Create a cursor to interact with the MySQL server
cursor = conn.cursor()

# %%
command = """
      SELECT
        *
      FROM
        my_guitar_shop.customers as c
"""

# Change the value of the command variable to test your queries, happy coding!

# %%
cursor.execute(command)

# Fetch all the results
records = cursor.fetchall()
import pandas as pd

df = pd.DataFrame(records)

display(df)
# Out:
#    0                            1                                         2  \
# 0  1     allan.sherwood@yahoo.com  650215acec746f0e32bdfff387439eefc1358737
# 1  2             barryz@gmail.com  3f563468d42a448cb1e56924529f6e7bbe529cc7
# 2  3      christineb@solarone.com  ed19f5c0833094026a2f1e9e6f08a35d26037066
# 3  4  david.goldstein@hotmail.com  b444ac06613fc8d63795be9ad0beaf55011936ac
# 4  5              erinv@gmail.com  109f4b3c50d7b0df729d299bc6f8e9ef9066971f
# 5  6    frankwilson@sbcglobal.net  3ebfa301dc59196f18593c45e519287a23297589
# 6  7     gary_hernandez@yahoo.com  1ff2b3704aede04eecb51e50ca698efd50a1379b
# 7  8         heatheresway@mac.com  911ddc3b8f9a13b5499b6bc4638a2b4f3f68bf23
#
#            3          4   5   6
# 0      Allan   Sherwood   1   2
# 1      Barry     Zimmer   3   3
# 2  Christine      Brown   4   4
# 3      David  Goldstein   5   6
# 4       Erin  Valentino   7   7
# 5  Frank Lee     Wilson   8   8
# 6       Gary  Hernandez   9  10
# ...
